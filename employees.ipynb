# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import numpy as np

# %%
# File Read Karna
df = pd.read_csv("employees.csv")
df = pd.DataFrame(df)
df
# Out:
#       ID   Name        City   Salary   Designation
# 0      1    Ali   Islamabad  65000.0        DevOps
# 1      2   Iqra  Faisalabad  55000.0        DevOps
# 2      3   Sara   Islamabad  70000.0  Data Analyst
# 3      4   Sara     Karachi      NaN    Junior Dev
# 4      5   Taha      Quetta  50000.0   ML Engineer
# ..   ...    ...         ...      ...           ...
# 195  196   Taha      Quetta  50000.0   ML Engineer
# 196  197   Hina      Lahore  60000.0        DevOps
# 197  198   Zain   Islamabad  50000.0   ML Engineer
# 198  199  Bilal   Islamabad  60000.0    Junior Dev
# 199  200   Noor      Multan  45000.0    Senior Dev
#
# [200 rows x 5 columns]

# %%
# First Rows Data Dekhna
df.head(60)
# Out:
#     ID    Name        City   Salary   Designation
# 0    1     Ali   Islamabad  65000.0        DevOps
# 1    2    Iqra  Faisalabad  55000.0        DevOps
# 2    3    Sara   Islamabad  70000.0  Data Analyst
# 3    4    Sara     Karachi      NaN    Junior Dev
# 4    5    Taha      Quetta  50000.0   ML Engineer
# 5    6     Ali   Islamabad  65000.0  Data Analyst
# 6    7    Hina      Lahore  60000.0        DevOps
# 7    8    Zain   Islamabad  50000.0   ML Engineer
# 8    9   Bilal   Islamabad  60000.0    Junior Dev
# 9   10    Noor      Multan  45000.0    Senior Dev
# 10  11     Ali   Islamabad  65000.0        DevOps
# 11  12    Iqra  Faisalabad  55000.0        DevOps
# 12  13    Sara   Islamabad  70000.0  Data Analyst
# 13  14    Sara     Karachi      NaN    Junior Dev
# 14  15    Taha      Quetta  50000.0   ML Engineer
# 15  16     Ali   Islamabad  65000.0  Data Analyst
# 16  17    Hina      Lahore  60000.0        DevOps
# 17  18    Zain   Islamabad  50000.0   ML Engineer
# ...

# %%
# Last Rows Data Dekhna
df.tail(40)
# Out:
#       ID    Name        City   Salary   Designation
# 160  161   Ahmed     Karachi  52000.0  Data Analyst
# 161  162  Ayesha      Lahore  58000.0    Junior Dev
# 162  163     Ali   Islamabad  65000.0        DevOps
# 163  164    Iqra  Faisalabad  55000.0        DevOps
# 164  165    Sara   Islamabad  70000.0  Data Analyst
# 165  166    Taha      Quetta  50000.0   ML Engineer
# 166  167    Hina      Lahore  60000.0        DevOps
# 167  168    Zain   Islamabad  50000.0   ML Engineer
# 168  169   Bilal   Islamabad  60000.0    Junior Dev
# 169  170    Noor      Multan  45000.0    Senior Dev
# 170  171   Ahmed     Karachi  52000.0  Data Analyst
# 171  172  Ayesha      Lahore  58000.0    Junior Dev
# 172  173     Ali   Islamabad  65000.0        DevOps
# 173  174    Iqra  Faisalabad  55000.0        DevOps
# 174  175    Sara   Islamabad  70000.0  Data Analyst
# 175  176    Taha      Quetta  50000.0   ML Engineer
# 176  177    Hina      Lahore  60000.0        DevOps
# ...

# %%
# Shape Rows & Columns Count Karte hai
df.shape
# Out:
# (200, 5)

# %%
# Column Names Dekhna
df.columns
# Out:
# Index(['ID', 'Name', 'City', 'Salary', 'Designation'], dtype='object')

# %%
# Data Types Dekhna
df.dtypes
# Out:
# ID               int64
# Name            object
# City            object
# Salary         float64
# Designation     object
# dtype: object

# %%
# Information Dekhna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           200 non-null    int64
#  1   Name         200 non-null    object
#  2   City         197 non-null    object
#  3   Salary       200 non-null    float64
#  4   Designation  197 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 7.9+ KB

# %%
# Statistics Dekhna
df.describe()
# Out:
#                ID        Salary
# count  200.000000    200.000000
# mean   100.500000  56690.721649
# std     57.879185   7206.726094
# min      1.000000  45000.000000
# 25%     50.750000  50000.000000
# 50%    100.500000  56690.721649
# 75%    150.250000  60000.000000
# max    200.000000  70000.000000

# %%
# Check Null Values
df.isnull()
# Count Null Values Check karna
df.isnull().sum()

# %%
# Fill Missing Values
# df["Salary"] = df["Salary"].fillna(40000)
# Column Mean Se Fill
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())

# %%
# Remove missing Values rows
# df.dropna

# %%
# Missing Values Counts
df["Salary"].isnull().sum()
# Out:
# np.int64(0)

# %%
# Column Selection
# Single Column Dekhna
df["Salary"]
# Out:
# 0      65000.000000
# 1      55000.000000
# 2      70000.000000
# 3      56690.721649
# 4      50000.000000
#            ...
# 195    50000.000000
# 196    60000.000000
# 197    50000.000000
# 198    60000.000000
# 199    45000.000000
# Name: Salary, Length: 200, dtype: float64

# %%
# Multiple Column Dekhna
df[["Name", "Salary"]]
# Out:
#       Name        Salary
# 0      Ali  65000.000000
# 1     Iqra  55000.000000
# 2     Sara  70000.000000
# 3     Sara  56690.721649
# 4     Taha  50000.000000
# ..     ...           ...
# 195   Taha  50000.000000
# 196   Hina  60000.000000
# 197   Zain  50000.000000
# 198  Bilal  60000.000000
# 199   Noor  45000.000000
#
# [200 rows x 2 columns]

# %%
# Row Selection
# Single Row Dekhna
df.iloc[1]
# Out:
# ID                      2
# Name                 Iqra
# City           Faisalabad
# Salary            55000.0
# Designation        DevOps
# Name: 1, dtype: object

# %%
# Multiple Rows Dekhna 
df.iloc[0:20]
# Out:
#     ID   Name        City        Salary   Designation
# 0    1    Ali   Islamabad  65000.000000        DevOps
# 1    2   Iqra  Faisalabad  55000.000000        DevOps
# 2    3   Sara   Islamabad  70000.000000  Data Analyst
# 3    4   Sara     Karachi  56690.721649    Junior Dev
# 4    5   Taha      Quetta  50000.000000   ML Engineer
# 5    6    Ali   Islamabad  65000.000000  Data Analyst
# 6    7   Hina      Lahore  60000.000000        DevOps
# 7    8   Zain   Islamabad  50000.000000   ML Engineer
# 8    9  Bilal   Islamabad  60000.000000    Junior Dev
# 9   10   Noor      Multan  45000.000000    Senior Dev
# 10  11    Ali   Islamabad  65000.000000        DevOps
# 11  12   Iqra  Faisalabad  55000.000000        DevOps
# 12  13   Sara   Islamabad  70000.000000  Data Analyst
# 13  14   Sara     Karachi  56690.721649    Junior Dev
# 14  15   Taha      Quetta  50000.000000   ML Engineer
# 15  16    Ali   Islamabad  65000.000000  Data Analyst
# ...

# %%
# Condition
df[df["Salary"] > 60000]
# Out:
#       ID  Name       City   Salary   Designation
# 0      1   Ali  Islamabad  65000.0        DevOps
# 2      3  Sara  Islamabad  70000.0  Data Analyst
# 5      6   Ali  Islamabad  65000.0  Data Analyst
# 10    11   Ali  Islamabad  65000.0        DevOps
# 12    13  Sara  Islamabad  70000.0  Data Analyst
# 15    16   Ali  Islamabad  65000.0  Data Analyst
# 22    23   Ali        NaN  65000.0        DevOps
# 24    25  Sara  Islamabad  70000.0           NaN
# 32    33   Ali  Islamabad  65000.0        DevOps
# 34    35  Sara  Islamabad  70000.0  Data Analyst
# 42    43   Ali  Islamabad  65000.0        DevOps
# 44    45  Sara  Islamabad  70000.0  Data Analyst
# 52    53   Ali  Islamabad  65000.0        DevOps
# 54    55  Sara  Islamabad  70000.0  Data Analyst
# 62    63   Ali  Islamabad  65000.0        DevOps
# 64    65  Sara  Islamabad  70000.0  Data Analyst
# 72    73   Ali  Islamabad  65000.0        DevOps
# 74    75  Sara  Islamabad  70000.0  Data Analyst
# ...
