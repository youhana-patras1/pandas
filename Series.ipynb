# %% [markdown]
# Install Pandas Library

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Install Numpy Library

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import Pandas Library

# %%
import pandas as pd

# %% [markdown]
# Import Numpy Library

# %%
import numpy as np

# %% [markdown]
# Python List String

# %%
# Custom Labels ke Sath
labels = ['a','b','c']

# %% [markdown]
# Python List Integer

# %%
# Agar aap is list ko ek column ki tarah dekhna chahte hain
my_list = [10,20,30]

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
# Series banate waqt labels ko index ke taur par istemal karein
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# Numpy Array

# %%
# Aik 1D array banana
arr = np.array([10,20,30])

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
