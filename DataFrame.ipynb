# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Pandas Library Import

# %%
import pandas as pd

# %% [markdown]
# Numpy Library Import

# %%
import numpy as np

# %%
Creating a DataFrame

# %%
data = {
    'Name':['Ali','Ahmed','Sara','Zain','Ayesha'],
    'City':['Karachi','Lahore','Islamabad','Multan','Multan'],
    'Salary':[50000,60000,70000,55000,65000]
}
pd.DataFrame(data)
# Out:
#      Name       City  Salary
# 0     Ali    Karachi   50000
# 1   Ahmed     Lahore   60000
# 2    Sara  Islamabad   70000
# 3    Zain     Multan   55000
# 4  Ayesha     Multan   65000

# %%
data_list = [
    ['Ali','Ahmed','Sara','Zain','Ayesha'],
    ['Karachi','Lahore','Islamabad','Multan','Multan'],
    [50000,60000,70000,55000,65000]
]
df2 = pd.DataFrame(data_list)

# %%
df2
# Out:
#          0       1          2       3       4
# 0      Ali   Ahmed       Sara    Zain  Ayesha
# 1  Karachi  Lahore  Islamabad  Multan  Multan
# 2    50000   60000      70000   55000   65000

# %% [markdown]
# Selection and Indexing of Columns

# %%
data_list = [
    ['Ali', 'Karachi', 50000],
    ['Ahmed', 'Lahore',60000],
    ['Sara', 'Islamabad', 70000],
    ['Zain','Multan', 55000],
    ['Ayesha', 'Multan', 65000]
]
df2 = pd.DataFrame(data_list)
columns = ['Name','City','Salary']
df2 = pd.DataFrame(data_list,columns =columns)
df2
# Out:
#      Name       City  Salary
# 0     Ali    Karachi   50000
# 1   Ahmed     Lahore   60000
# 2    Sara  Islamabad   70000
# 3    Zain     Multan   55000
# 4  Ayesha     Multan   65000

# %%
df2['Name']
# Out:
# 0       Ali
# 1     Ahmed
# 2      Sara
# 3      Zain
# 4    Ayesha
# Name: Name, dtype: object

# %%
df2[['Name','City']]
# Out:
#      Name       City
# 0     Ali    Karachi
# 1   Ahmed     Lahore
# 2    Sara  Islamabad
# 3    Zain     Multan
# 4  Ayesha     Multan

# %% [markdown]
# Creating a new column

# %%
df2['Designation'] = ['Software Engineer','Frontend Developer','Backend Developer','Full Stack Developer','Software Architect']

# %%
df2
# Out:
#      Name       City  Salary           Designation
# 0     Ali    Karachi   50000     Software Engineer
# 1   Ahmed     Lahore   60000    Frontend Developer
# 2    Sara  Islamabad   70000     Backend Developer
# 3    Zain     Multan   55000  Full Stack Developer
# 4  Ayesha     Multan   65000    Software Architect
