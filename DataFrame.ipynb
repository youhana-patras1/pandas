# %% [markdown]
# Install Pandas Library

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\ATIF\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\ATIF\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ATIF\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\ATIF\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\ATIF\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in C:\Users\ATIF\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Install Numpy Library

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in C:\Users\ATIF\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import Pandas Library

# %%
import pandas as pd

# %% [markdown]
# Import Numpy Library

# %%
import numpy as np

# %% [markdown]
# Creating DataFrame Python Dictionary

# %%
data = {
    'Name': ['Ali', 'Ahmed', 'Sara', 'Zain', 'Ayesha'],
    'City': ['Karachi', 'Lahore', 'Islamabad', 'Multan', 'Peshawar'],
    'Salary': [55000, 62000, 75000, 48000, 51000]
}
df = pd.DataFrame(data)
df
# Out:
#      Name       City  Salary
# 0     Ali    Karachi   55000
# 1   Ahmed     Lahore   62000
# 2    Sara  Islamabad   75000
# 3    Zain     Multan   48000
# 4  Ayesha   Peshawar   51000

# %% [markdown]
# Creating DataFrame Python List

# %%
data_list = [
    ['Ali', 'Karachi', 55000],
    ['Ahmed', 'Lahore', 62000],
    ['Sara', 'Islamabad', 75000],
    ['Zain', 'Multan', 48000],
    ['Ayesha', 'Peshawar', 51000]
]
df2 = pd.DataFrame(data_list)
df2
# Out:
#         0          1      2
# 0     Ali    Karachi  55000
# 1   Ahmed     Lahore  62000
# 2    Sara  Islamabad  75000
# 3    Zain     Multan  48000
# 4  Ayesha   Peshawar  51000

# %%
data_list = [
    ['Ali', 'Karachi', 55000],
    ['Ahmed', 'Lahore', 62000],
    ['Sara', 'Islamabad', 75000],
    ['Zain', 'Multan', 48000],
    ['Ayesha', 'Peshawar', 51000]
]
df2 = pd.DataFrame(data_list)
df2 = pd.DataFrame(data_list,columns=['Name','City','Salary'])
df2
# Out:
#      Name       City  Salary
# 0     Ali    Karachi   55000
# 1   Ahmed     Lahore   62000
# 2    Sara  Islamabad   75000
# 3    Zain     Multan   48000
# 4  Ayesha   Peshawar   51000

# %%
df2['Name']
# Out:
# 0       Ali
# 1     Ahmed
# 2      Sara
# 3      Zain
# 4    Ayesha
# Name: Name, dtype: object

# %%
df[['Name','City']]
# Out:
#      Name       City
# 0     Ali    Karachi
# 1   Ahmed     Lahore
# 2    Sara  Islamabad
# 3    Zain     Multan
# 4  Ayesha   Peshawar

# %% [markdown]
# Creating a new column

# %%
df2["Designation"] = ['Junior Developer','Backend Engineer', 'Senior Developer', 
'DevOps Engineer', 'Full Stack Developer']

# %%
df2
# Out:
#      Name       City  Salary           Designation
# 0     Ali    Karachi   55000      Junior Developer
# 1   Ahmed     Lahore   62000      Backend Engineer
# 2    Sara  Islamabad   75000      Senior Developer
# 3    Zain     Multan   48000       DevOps Engineer
# 4  Ayesha   Peshawar   51000  Full Stack Developer

# %% [markdown]
# Removing Columns

# %%
df2.drop('Designation',axis = 1)
# Out:
#      Name       City  Salary
# 0     Ali    Karachi   55000
# 1   Ahmed     Lahore   62000
# 2    Sara  Islamabad   75000
# 3    Zain     Multan   48000
# 4  Ayesha   Peshawar   51000

# %%
df2
# Out:
#      Name       City  Salary           Designation
# 0     Ali    Karachi   55000      Junior Developer
# 1   Ahmed     Lahore   62000      Backend Engineer
# 2    Sara  Islamabad   75000      Senior Developer
# 3    Zain     Multan   48000       DevOps Engineer
# 4  Ayesha   Peshawar   51000  Full Stack Developer

# %%
df2.drop('Designation',axis = 1, inplace=True)

# %%
df2
# Out:
#      Name       City  Salary
# 0     Ali    Karachi   55000
# 1   Ahmed     Lahore   62000
# 2    Sara  Islamabad   75000
# 3    Zain     Multan   48000
# 4  Ayesha   Peshawar   51000

# %%
df2.drop(['City','Salary'],axis = 1)
# Out:
#      Name
# 0     Ali
# 1   Ahmed
# 2    Sara
# 3    Zain
# 4  Ayesha

# %%
df2
# Out:
#      Name       City  Salary
# 0     Ali    Karachi   55000
# 1   Ahmed     Lahore   62000
# 2    Sara  Islamabad   75000
# 3    Zain     Multan   48000
# 4  Ayesha   Peshawar   51000

# %%
df2.drop(0,axis = 0)
# Out:
#      Name       City  Salary
# 1   Ahmed     Lahore   62000
# 2    Sara  Islamabad   75000
# 3    Zain     Multan   48000
# 4  Ayesha   Peshawar   51000

# %%
df2
# Out:
#      Name       City  Salary
# 0     Ali    Karachi   55000
# 1   Ahmed     Lahore   62000
# 2    Sara  Islamabad   75000
# 3    Zain     Multan   48000
# 4  Ayesha   Peshawar   51000

# %% [markdown]
# Selecting Rows

# %%
df2
# Out:
#      Name       City  Salary
# 0     Ali    Karachi   55000
# 1   Ahmed     Lahore   62000
# 2    Sara  Islamabad   75000
# 3    Zain     Multan   48000
# 4  Ayesha   Peshawar   51000

# %%
df2.loc[0]
# Out:
# Name          Ali
# City      Karachi
# Salary      55000
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#     Name     City  Salary
# 0    Ali  Karachi   55000
# 1  Ahmed   Lahore   62000

# %% [markdown]
# Selecting Subsets of Rows and Columns

# %%
df.loc[[0,1]][['City','Salary']]
# Out:
#       City  Salary
# 0  Karachi   55000
# 1   Lahore   62000
