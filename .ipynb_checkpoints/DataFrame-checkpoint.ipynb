# %% [markdown]
# Install Pandas Library

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Install Numpy Library

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Pandas Library Import

# %%
import pandas as pd

# %% [markdown]
# Numpy Library Import

# %%
import numpy as np

# %% [markdown]
# Creating DataFrame Python Dictionary

# %%
data = {
    'Name': ['Ali', 'Ahmed', 'Sara', 'Zain', 'Ayesha'],
    'City': ['Karachi', 'Lahore', 'Islamabad', 'Multan', 'Peshawar'],
    'Salary': [55000, 62000, 75000, 48000, 51000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name       City  Salary
# 0     Ali    Karachi   55000
# 1   Ahmed     Lahore   62000
# 2    Sara  Islamabad   75000
# 3    Zain     Multan   48000
# 4  Ayesha   Peshawar   51000

# %% [markdown]
# Creating DataFrame Python List

# %%
data_list = [
    ['Ali', 'Karachi', 55000],
    ['Ahmed', 'Lahore', 62000],
    ['Sara', 'Islamabad', 75000],
    ['Zain', 'Multan', 48000],
    ['Ayesha', 'Peshawar', 51000]
]
df2 = pd.DataFrame(data_list)

# %%
df2
# Out:
#         0          1      2
# 0     Ali    Karachi  55000
# 1   Ahmed     Lahore  62000
# 2    Sara  Islamabad  75000
# 3    Zain     Multan  48000
# 4  Ayesha   Peshawar  51000

# %%
data_list = [
    ['Ali', 'Karachi', 55000],
    ['Ahmed', 'Lahore', 62000],
    ['Sara', 'Islamabad', 75000],
    ['Zain', 'Multan', 48000],
    ['Ayesha', 'Peshawar', 51000]
]
df2 = pd.DataFrame(data_list)
df2 = pd.DataFrame(data_list, columns=['Name', 'City', 'Salary'])
df2
# Out:
#      Name       City  Salary
# 0     Ali    Karachi   55000
# 1   Ahmed     Lahore   62000
# 2    Sara  Islamabad   75000
# 3    Zain     Multan   48000
# 4  Ayesha   Peshawar   51000

# %% [markdown]
# Selection and Indexing of Columns

# %%
df2['Name']
# Out:
# 0       Ali
# 1     Ahmed
# 2      Sara
# 3      Zain
# 4    Ayesha
# Name: Name, dtype: object

# %%
df2[['Name','City']]
# Out:
#      Name       City
# 0     Ali    Karachi
# 1   Ahmed     Lahore
# 2    Sara  Islamabad
# 3    Zain     Multan
# 4  Ayesha   Peshawar
